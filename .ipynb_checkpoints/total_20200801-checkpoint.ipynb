# %%
import pandas as pd

aligned_result_r5 = pd.read_csv('./round05_election_result_aligned.csv')
aligned_result_r5_df = pd.DataFrame(aligned_result_r5, columns=['광역시도', 'hannara_rate', 'minju_rate', 'gita_rate'])
aligned_result_r6 = pd.read_csv('./round06_election_result_aligned.csv')
aligned_result_r6_df = pd.DataFrame(aligned_result_r6, columns=['광역시도', 'minju_rate', 'saenuri_rate', 'gita_rate'])
aligned_result_r7 = pd.read_csv('./round07_election_result_aligned.csv')
aligned_result_r7_df = pd.DataFrame(aligned_result_r7, columns=['광역시도', 'minju_rate', 'hanguk_rate', 'gita_rate'])

# print(aligned_result_r5_df, '\n')
# print(aligned_result_r6_df, '\n')
# print(aligned_result_r7_df)
# Out:
#        광역시도  hannara_rate  minju_rate  gita_rate
# 0       강원도      0.439666    0.523703   0.036631
# 1       경기도      0.500906    0.458654   0.040440
# 2      경상남도      0.455566    0.000000   0.544434
# 3      경상북도      0.724908    0.113714   0.161378
# 4     광주광역시      0.140573    0.560488   0.298939
# 5     대구광역시      0.714552    0.165296   0.120152
# 6     대전광역시      0.282589    0.230861   0.486550
# 7     부산광역시      0.546410    0.439369   0.014221
# 8     서울특별시      0.471315    0.465348   0.063337
# 9     울산광역시      0.604673    0.288760   0.106567
# 10    인천광역시      0.439410    0.521722   0.038868
# 11     전라남도      0.127720    0.651255   0.221025
# 12     전라북도      0.176454    0.665778   0.157768
# 13  제주특별자치도      0.000000    0.392471   0.607529
# 14     충청남도      0.171559    0.407255   0.421186
# 15     충청북도      0.450386    0.502465   0.047149
#
#        광역시도  minju_rate  saenuri_rate  gita_rate
# 0       강원도    0.488045      0.472511   0.039444
# 1       경기도    0.480870      0.490100   0.029030
# 2      경상남도    0.351876      0.574434   0.073691
# 3      경상북도    0.144193      0.750605   0.105202
# 4     광주광역시    0.564921      0.033252   0.401827
# 5     대구광역시    0.397944      0.552113   0.049943
# 6     대전광역시    0.494525      0.461778   0.043697
# 7     부산광역시    0.000000      0.489775   0.510225
# 8     서울특별시    0.556118      0.426331   0.017551
# 9   세종특별자치시    0.568970      0.415707   0.015323
# 10    울산광역시    0.000000      0.598403   0.401597
# 11    인천광역시    0.476942      0.494235   0.028823
# 12     전라남도    0.731359      0.096135   0.172506
# 13     전라북도    0.662649      0.200602   0.136748
# 14  제주특별자치도    0.339193      0.589088   0.071720
# 15     충청남도    0.508613      0.428195   0.063192
# 16     충청북도    0.487302      0.467111   0.045587
#
#        광역시도  minju_rate  hanguk_rate  gita_rate
# 0       강원도    0.632875     0.344798   0.022327
# 1       경기도    0.553927     0.348800   0.097273
# 2      경상남도    0.517476     0.420915   0.061609
# 3      경상북도    0.331081     0.502755   0.166164
# 4     광주광역시    0.826782     0.049675   0.123543
# 5     대구광역시    0.390788     0.528172   0.081040
# 6     대전광역시    0.556384     0.317272   0.126344
# 7     부산광역시    0.544352     0.366274   0.089373
# 8     서울특별시    0.521906     0.230816   0.247278
# 9   세종특별자치시    0.704171     0.178383   0.117447
# 10    울산광역시    0.519637     0.393771   0.086593
# 11    인천광역시    0.567931     0.349079   0.082990
# 12     전라남도    0.739765     0.036889   0.223346
# 13     전라북도    0.684435     0.026467   0.289099
# 14  제주특별자치도    0.392944     0.032031   0.575025
# 15     충청남도    0.608900     0.341666   0.049434
# 16     충청북도    0.599182     0.290638   0.110179

# %%
rnd_list = ['r5', 'r6', 'r7']
party_list = ['jinbo_1dang', 'bosu_1dang', 'gita_dang']
province_list = ['Gangwon', 'Gyeonggi', 'Gyeongnam', 'Gyeongbuk', 'Gwangju', 'Daegu',
           'Daejeon', 'Busan', 'Seoul', 'Sejong', 'Ulsan', 'Incheon', 'Jeonnam', 
            'Jeonbuk', 'Jeju', 'Chungnam', 'Chungbuk']

province_old_list = province_list.copy()
province_old_list.remove('Sejong')

final_row_list = []
for i in rnd_list:
    for j in party_list:
        if(i == 'r5'):
            p_list = province_old_list
        else:
            p_list = province_list
        
        for k in p_list:
            final_row_list.append(i + '_' + j + '_' + k)
     
arr_r5 = aligned_result_r5_df.values.copy()
arr_r5.resize(16*4, 1)
arr_r5_list = [arr_r5[i] for i in range(16*4) if i%4 != 0]
arr_r5_list_df = pd.DataFrame(arr_r5_list)

arr_r6 = aligned_result_r6_df.values.copy()
arr_r6.resize(17*4, 1)
arr_r6_list = [arr_r6[i] for i in range(17*4) if i%4 != 0]
arr_r6_list_df = pd.DataFrame(arr_r6_list)

arr_r7 = aligned_result_r7_df.values.copy()
arr_r7.resize(17*4, 1)
arr_r7_list = [arr_r7[i] for i in range(17*4) if i%4 != 0]
arr_r7_list_df = pd.DataFrame(arr_r7_list)

final_row_value_df = pd.concat([arr_r5_list_df, arr_r6_list_df, arr_r7_list_df])
final_row_value_df.index = final_row_list
final_row_value_df.columns = ['rate']
final_row_value_df
# Out:
#                               rate
# r5_jinbo_1dang_Gangwon    0.439666
# r5_jinbo_1dang_Gyeonggi   0.523703
# r5_jinbo_1dang_Gyeongnam  0.036631
# r5_jinbo_1dang_Gyeongbuk  0.500906
# r5_jinbo_1dang_Gwangju    0.458654
# ...                            ...
# r7_gita_dang_Jeonnam      0.341666
# r7_gita_dang_Jeonbuk      0.049434
# r7_gita_dang_Jeju         0.599182
# r7_gita_dang_Chungnam     0.290638
# r7_gita_dang_Chungbuk     0.110179
#
# [150 rows x 1 columns]

# %%
import sys
import numpy as np

def KL(P,Q):
    epsilon = 0.00001

    # You may want to instead make copies to avoid changing the np arrays.
    P = P+epsilon
    Q = Q+epsilon

    divergence = np.sum(P*np.log(P/Q))
    return divergence

data_list = final_row_value_df.rate.to_list()
KL_result = []
for a in data_list:
    for b in data_list:
        KL_result.append(KL(a, b))

KL_result_reshaped = np.reshape(KL_result, (150,150))

KL_result_df = pd.DataFrame(KL_result_reshaped)
KL_result_df.index = final_row_list
KL_result_df.columns = final_row_list
KL_result_df
# Out:
#                           r5_jinbo_1dang_Gangwon  r5_jinbo_1dang_Gyeonggi  \
# r5_jinbo_1dang_Gangwon                  0.000000                -0.076902
# r5_jinbo_1dang_Gyeonggi                 0.091600                 0.000000
# r5_jinbo_1dang_Gyeongnam               -0.091048                -0.097457
# r5_jinbo_1dang_Gyeongbuk                0.065319                -0.022294
# r5_jinbo_1dang_Gwangju                  0.019392                -0.060830
# ...                                          ...                      ...
# r7_gita_dang_Jeonnam                   -0.086162                -0.145923
# r7_gita_dang_Jeonbuk                   -0.108045                -0.116693
# r7_gita_dang_Jeju                       0.185477                 0.080675
# r7_gita_dang_Chungnam                  -0.120307                -0.171142
# r7_gita_dang_Chungbuk                  -0.152484                -0.171757
#
#                           r5_jinbo_1dang_Gyeongnam  r5_jinbo_1dang_Gyeongbuk  \
# r5_jinbo_1dang_Gangwon                    1.092540                 -0.057333
# r5_jinbo_1dang_Gyeonggi                   1.392961                  0.023308
# r5_jinbo_1dang_Gyeongnam                  0.000000                 -0.095826
# r5_jinbo_1dang_Gyeongbuk                  1.310031                  0.000000
# r5_jinbo_1dang_Gwangju                    1.159115                 -0.040417
# ...                                            ...                       ...
# r7_gita_dang_Jeonnam                      0.762859                 -0.130717
# r7_gita_dang_Jeonbuk                      0.014817                 -0.114493
# r7_gita_dang_Jeju                         1.674394                  0.107342
# r7_gita_dang_Chungnam                     0.601918                 -0.158207
# r7_gita_dang_Chungbuk                     0.121322                 -0.166853
#
#                           r5_jinbo_1dang_Gwangju  r5_jinbo_1dang_Daegu  \
# r5_jinbo_1dang_Gangwon                 -0.018589              1.049053
# r5_jinbo_1dang_Gyeonggi                 0.069457              1.341162
# r5_jinbo_1dang_Gyeongnam               -0.092597             -0.003624
# r5_jinbo_1dang_Gyeongbuk                0.044140              1.260487
# r5_jinbo_1dang_Gwangju                  0.000000              1.113750
# ...                                          ...                   ...
# r7_gita_dang_Jeonnam                   -0.100608              0.729065
# r7_gita_dang_Jeonbuk                   -0.110136              0.009927
# r7_gita_dang_Jeju                       0.160143              1.615130
# r7_gita_dang_Chungnam                  -0.132595              0.573171
# r7_gita_dang_Chungbuk                  -0.157143              0.110424
#
#                           r5_jinbo_1dang_Daejeon  r5_jinbo_1dang_Busan  \
# r5_jinbo_1dang_Gangwon                 -0.015619              4.700670
# r5_jinbo_1dang_Gyeonggi                 0.072996              5.690724
# r5_jinbo_1dang_Gyeongnam               -0.092350              0.300687
# r5_jinbo_1dang_Gyeongbuk                0.047524              5.420712
# r5_jinbo_1dang_Gwangju                  0.003099              4.923068
# ...                                          ...                   ...
# r7_gita_dang_Jeonnam                   -0.098300              3.566767
# r7_gita_dang_Jeonbuk                   -0.109802              0.420572
# r7_gita_dang_Jeju                       0.164191              6.591568
# r7_gita_dang_Chungnam                  -0.130631              2.987075
# r7_gita_dang_Chungbuk                  -0.156399              1.025572
#
#                           r5_jinbo_1dang_Seoul  r5_jinbo_1dang_Ulsan  ...  \
# r5_jinbo_1dang_Gangwon               -0.093970             -0.219847  ...
# r5_jinbo_1dang_Gyeonggi              -0.020331             -0.170267  ...
# r5_jinbo_1dang_Gyeongnam             -0.098879             -0.109369  ...
# r5_jinbo_1dang_Gyeongbuk             -0.041740             -0.185149  ...
# r5_jinbo_1dang_Gwangju               -0.078636             -0.209949  ...
# ...                                        ...                   ...  ...
# r7_gita_dang_Jeonnam                 -0.159188             -0.257007  ...
# r7_gita_dang_Jeonbuk                 -0.118613             -0.132768  ...
# r7_gita_dang_Jeju                     0.057413             -0.114131  ...
# r7_gita_dang_Chungnam                -0.182426             -0.265636  ...
# r7_gita_dang_Chungbuk                -0.176035             -0.207581  ...
#
#                           r7_gita_dang_Busan  r7_gita_dang_Seoul  \
# r5_jinbo_1dang_Gangwon              0.184328            0.049396
# r5_jinbo_1dang_Gyeonggi             0.311159            0.150437
# r5_jinbo_1dang_Gyeongnam           -0.075687           -0.086932
# r5_jinbo_1dang_Gyeongbuk            0.275321            0.121595
# r5_jinbo_1dang_Gwangju              0.211681            0.070921
# ...                                      ...                 ...
# r7_gita_dang_Jeonnam                0.057080           -0.047777
# r7_gita_dang_Jeonbuk               -0.087316           -0.102490
# r7_gita_dang_Jeju                   0.436680            0.252793
# r7_gita_dang_Chungnam               0.001544           -0.087653
# r7_gita_dang_Chungbuk              -0.106289           -0.140105
#
#                           r7_gita_dang_Sejong  r7_gita_dang_Ulsan  \
# r5_jinbo_1dang_Gangwon               1.151524           -0.118006
# r5_jinbo_1dang_Gyeonggi              1.463218           -0.048961
# r5_jinbo_1dang_Gyeongnam             0.004915           -0.100882
# r5_jinbo_1dang_Gyeongbuk             1.377230           -0.069123
# r5_jinbo_1dang_Gwangju               1.220646           -0.103710
# ...                                       ...                 ...
# r7_gita_dang_Jeonnam                 0.808696           -0.177866
# r7_gita_dang_Jeonbuk                 0.021450           -0.121315
# r7_gita_dang_Jeju                    1.754778            0.024658
# r7_gita_dang_Chungnam                0.640909           -0.198314
# r7_gita_dang_Chungbuk                0.136104           -0.182058
#
#                           r7_gita_dang_Incheon  r7_gita_dang_Jeonnam  \
# r5_jinbo_1dang_Gangwon               -0.143173              0.110876
# r5_jinbo_1dang_Gyeonggi              -0.078938              0.223668
# r5_jinbo_1dang_Gyeongnam             -0.102979             -0.081808
# r5_jinbo_1dang_Gyeongbuk             -0.097795              0.191638
# r5_jinbo_1dang_Gwangju               -0.129963              0.135056
# ...                                        ...                   ...
# r7_gita_dang_Jeonnam                 -0.197423              0.000000
# r7_gita_dang_Jeonbuk                 -0.124146             -0.095576
# r7_gita_dang_Jeju                    -0.009640              0.336578
# r7_gita_dang_Chungnam                -0.214951             -0.047012
# r7_gita_dang_Chungbuk                -0.188365             -0.124697
#
#                           r7_gita_dang_Jeonbuk  r7_gita_dang_Jeju  \
# r5_jinbo_1dang_Gangwon                0.960778          -0.136099
# r5_jinbo_1dang_Gyeonggi               1.236015          -0.070512
# r5_jinbo_1dang_Gyeongnam             -0.010980          -0.102390
# r5_jinbo_1dang_Gyeongbuk              1.159917          -0.089737
# r5_jinbo_1dang_Gwangju                1.021663          -0.122585
# ...                                        ...                ...
# r7_gita_dang_Jeonnam                  0.660466          -0.191926
# r7_gita_dang_Jeonbuk                  0.000000          -0.123350
# r7_gita_dang_Jeju                     1.494829           0.000000
# r7_gita_dang_Chungnam                 0.514817          -0.210275
# r7_gita_dang_Chungbuk                 0.088301          -0.186593
#
#                           r7_gita_dang_Chungnam  r7_gita_dang_Chungbuk
# r5_jinbo_1dang_Gangwon                 0.181993               0.608441
# r5_jinbo_1dang_Gyeonggi                0.308378               0.816334
# r5_jinbo_1dang_Gyeongnam              -0.075881              -0.040343
# r5_jinbo_1dang_Gyeongbuk               0.272660               0.758505
# r5_jinbo_1dang_Gwangju                 0.209245               0.654110
# ...                                         ...                    ...
# r7_gita_dang_Jeonnam                   0.055266               0.386662
# r7_gita_dang_Jeonbuk                  -0.087579              -0.039622
# r7_gita_dang_Jeju                      0.433497               1.014662
# r7_gita_dang_Chungnam                  0.000000               0.281904
# r7_gita_dang_Chungbuk                 -0.106874               0.000000
#
# [150 rows x 150 columns]
